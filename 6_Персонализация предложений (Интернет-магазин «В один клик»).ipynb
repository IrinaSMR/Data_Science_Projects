# %% [markdown]
# # Персонализация предложений постоянным клиентам Интернет-магазина «В один клик» для увеличения пользовательской акивности

# %% [markdown]
# Интернет-магазин «В один клик» продаёт разные товары: для детей, для дома, мелкую бытовую технику, косметику и даже продукты. Отчёт магазина за прошлый период показал, что активность покупателей начала снижаться. Привлекать новых клиентов уже не так эффективно: о магазине и так знает большая часть целевой аудитории. Возможный выход — удерживать активность постоянных клиентов. Сделать это можно с помощью персонализированных предложений.
#
# **Цель проекта**
#
# Разработка решения, которое позволит персонализировать предложения постоянным клиентам, чтобы увеличить их покупательскую активность.

# %% [markdown]
# **Описание данных**

# %% [markdown]
# Для работы предоставлено четыре датасета: `market_file.csv`, `market_money.csv`, `market_time.csv`, `money.csv`.
#
# Файл `market_file.csv` содержит данные о поведении покупателя на сайте, о коммуникациях с покупателем и его продуктовом поведении.
#
# * `id` — номер покупателя в корпоративной базе данных.
# * `Покупательская активность` — рассчитанный класс покупательской активности (целевой признак): «снизилась» или «прежний уровень».
# * `Тип сервиса` — уровень сервиса, например «премиум» и «стандарт».
# * `Разрешить сообщать` — информация о том, можно ли присылать покупателю дополнительные предложения о товаре. Согласие на это даёт покупатель.
# * `Маркет_актив_6_мес` — среднемесячное значение маркетинговых коммуникаций компании, которое приходилось на покупателя за последние 6 месяцев. Это значение показывает, какое число рассылок, звонков, показов рекламы и прочего приходилось на клиента.
# * `Маркет_актив_тек_мес` — количество маркетинговых коммуникаций в текущем месяце.
# * `Длительность` — значение, которое показывает, сколько дней прошло с момента регистрации покупателя на сайте.
# * `Акционные_покупки` — среднемесячная доля покупок по акции от общего числа покупок за последние 6 месяцев.
# * `Популярная_категория` — самая популярная категория товаров у покупателя за последние 6 месяцев.
# * `Средний_просмотр_категорий_за_визит` — показывает, сколько в среднем категорий покупатель просмотрел за визит в течение последнего месяца.
# * `Неоплаченные_продукты_штук_квартал` — общее число неоплаченных товаров в корзине за последние 3 месяца.
# * `Ошибка_сервиса` — число сбоев, которые коснулись покупателя во время посещения сайта.
# * `Страниц_за_визит` — среднее количество страниц, которые просмотрел покупатель за один визит на сайт за последние 3 месяца.
#
# Файл `market_money.csv` содержит данные о выручке, которую получает магазин с покупателя, то есть сколько покупатель всего потратил за период взаимодействия с сайтом.
#
# * `id` — номер покупателя в корпоративной базе данных.
# * `Период` — название периода, во время которого зафиксирована выручка. Например, `текущий_месяц` или `предыдущий_месяц`.
# * `Выручка` — сумма выручки за период.
#
# Файл `market_time.csv` содержит данные о времени (в минутах), которое покупатель провёл на сайте в течение периода.
#
# * `id` — номер покупателя в корпоративной базе данных.
# * `Период` — название периода, во время которого зафиксировано общее время.
# * `минут` — значение времени, проведённого на сайте, в минутах.
#
# Файл `money.csv` содержит данные о среднемесячной прибыли покупателя за последние 3 месяца: какую прибыль получает магазин от продаж каждому покупателю.
#
# * `id` — номер покупателя в корпоративной базе данных.
# * `Прибыль` — значение прибыли.

# %% [markdown]
# # План работы

# %% [markdown]
# 1. **Загрузка данных и их изучение**
#
# * Открыть предоставленные файлы и ознакомиться с данными.
# * Убедиться, что данные в таблицах соответствуют описанию.
#
# 2. **Предобработка данных**
#
# Провести необходимую предобработку данных.
#
# 3. **Исследовательский анализ данных**
#
# Провести исследовательский анализ данных из каждой таблицы. Отобрать клиентов с покупательской активностью не менее трёх месяцев, то есть таких, которые что-либо покупали в этот период. Оформить выводы по результатам шага.
#
# 4. **Объединение таблиц**
#
# 4.1 Объединить таблицы market_file.csv, market_money.csv, market_time.csv. Данные о прибыли из файла money.csv при моделировании не понадобятся.
#
# 4.2 Учесть, что данные о выручке и времени на сайте находятся в одном столбце для всех периодов. В итоговой таблице сделать отдельный столбец для каждого периода.
#
#
# 5. **Корреляционный анализ**
#
# Провести корреляционный анализ признаков в количественной шкале в итоговой таблице для моделирования. Сделать выводы о мультиколлинеарности и при необходимости устраните её.
#
# 6. **Использование пайплайнов**
#
# Применить все изученные модели. Для этого использовать пайплайны.
#
# * Во время подготовки данных использовать `ColumnTransformer`. Количественные и категориальные признаки обработать в пайплайне раздельно. Для кодирования категориальных признаков использовать как минимум два кодировщика, для масштабирования количественных — как минимум два скейлера. Для каждой модели можно подготовить данные с разным кодированием и масштабированием.
# * Обучить четыре модели: `KNeighborsClassifier()`, `DecisionTreeClassifier()`, `LogisticRegression()` и `SVC()`. Для каждой из них подобрать как минимум один гиперпараметр. Выбрать подходящую для задачи метрику, аргументировать свой выбор. Использовать эту метрику при подборе гиперпараметров.
# * Выбрать лучшую модель, используя заданную метрику. Для этого применить одну из стратегий:
#     - использовать пайплайны и инструменты подбора гиперпараметров для каждой модели отдельно, чтобы выбрать лучшую модель     самостоятельно;
#     - использовать один общий пайплайн для всех моделей и инструмент подбора гиперпараметров, который вернёт вам лучшую модель.
#
# 7. **Анализ важности признаков**
#
# * Оценить важность признаков для лучшей модели и построить график важности с помощью метода `SHAP`.
# * Сделать выводы о значимости признаков:
#     - какие признаки мало значимы для модели;
#     - какие признаки сильнее всего влияют на целевой признак;
#     - как можно использовать эти наблюдения при моделировании и принятии бизнес-решений.
#
# 8. **Сегментация покупателей**
#
# * Выполнить сегментацию покупателей. Использовать результаты моделирования и данные о прибыльности покупателей.
# * Выбрать группу покупателей и предложить, как увеличить её покупательскую активность:
#     - Провести графическое и аналитическое исследование группы покупателей.
#     - Сделать предложения по работе с сегментом для увеличения покупательской активности.
# * Сделать выводы о сегментах:
#     - какой сегмент выбран для дополнительного исследования,
#     - какие предложения сделаны и почему.
#
# 9. **Общий вывод**
#
# * Описать задачу.
# * Описать исходные данные и проведённую предобработку.
# * Описать, что было сделано для поиска лучшей модели.
# * Указать лучшую модель.
# * Добавить выводы и дополнительные предложения для выбранного сегмента покупателей.

# %% [markdown]
# ## Загрузка данных и их изучение

# %%
# установим недостающие библиотеки
! pip install shap -q
! pip install phik -q
! pip install scikit-learn==1.3.2 -q

# %%
# импортируем необходимые для работы библиотеки
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import shap
import phik

from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split, RandomizedSearchCV
from sklearn.preprocessing import MinMaxScaler, OneHotEncoder, OrdinalEncoder, StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.metrics import roc_auc_score

pd.set_option('display.max_columns', None)

# %matplotlib inline

# %%
# сохраним датафреймы в переменные
market_file = pd.read_csv('datasets/market_file.csv')
market_money = pd.read_csv('datasets/market_money.csv')
market_time = pd.read_csv('datasets/market_time.csv')
money = pd.read_csv('datasets/money.csv', sep=';', decimal=',')

# %%
# просмотрим первые строки первого датафрейма
market_file.head()
# Out:
#        id Покупательская активность Тип сервиса Разрешить сообщать  \
# 0  215348                 Снизилась     премиум                 да
# 1  215349                 Снизилась     премиум                 да
# 2  215350                 Снизилась   стандартт                нет
# 3  215351                 Снизилась   стандартт                 да
# 4  215352                 Снизилась   стандартт                нет
#
#    Маркет_актив_6_мес  Маркет_актив_тек_мес  Длительность  Акционные_покупки  \
# 0                 3.4                     5           121               0.00
# 1                 4.4                     4           819               0.75
# 2                 4.9                     3           539               0.14
# 3                 3.2                     5           896               0.99
# 4                 5.1                     3          1064               0.94
#
#   Популярная_категория  Средний_просмотр_категорий_за_визит  \
# ...

# %%
# просмотрим общую информацию о датафрейме
market_file.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1300 entries, 0 to 1299
# Data columns (total 13 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   id                                   1300 non-null   int64
#  1   Покупательская активность            1300 non-null   object
#  2   Тип сервиса                          1300 non-null   object
#  3   Разрешить сообщать                   1300 non-null   object
#  4   Маркет_актив_6_мес                   1300 non-null   float64
#  5   Маркет_актив_тек_мес                 1300 non-null   int64
#  6   Длительность                         1300 non-null   int64
#  7   Акционные_покупки                    1300 non-null   float64
#  8   Популярная_категория                 1300 non-null   object
#  9   Средний_просмотр_категорий_за_визит  1300 non-null   int64
#  10  Неоплаченные_продукты_штук_квартал   1300 non-null   int64
# ...

# %% [markdown]
# Датафрейм `market_file` состоит из `1300` строк и `13` столбцов, пропусков нет, данные представлены целочисленными, вещественными и строковыми значениями.

# %%
# просмотрим первые строки второго датафрейма
market_money.head()
# Out:
#        id               Период  Выручка
# 0  215348  препредыдущий_месяц      0.0
# 1  215348        текущий_месяц   3293.1
# 2  215348     предыдущий_месяц      0.0
# 3  215349  препредыдущий_месяц   4472.0
# 4  215349        текущий_месяц   4971.6

# %%
# просмотрим общую информацию о датафрейме
market_money.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3900 entries, 0 to 3899
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   id       3900 non-null   int64
#  1   Период   3900 non-null   object
#  2   Выручка  3900 non-null   float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 91.5+ KB

# %% [markdown]
# Датафрейм `market_money` состоит из `3900` строк и `3` столбцов, пропусков нет, данные представлены целочисленными, вещественными и строковыми значениями.

# %%
# просмотрим первые строки третьего датафрейма
market_time.head()
# Out:
#        id            Период  минут
# 0  215348     текущий_месяц     14
# 1  215348  предыдцщий_месяц     13
# 2  215349     текущий_месяц     10
# 3  215349  предыдцщий_месяц     12
# 4  215350     текущий_месяц     13

# %%
# просмотрим общую информацию о датафрейме
market_time.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2600 entries, 0 to 2599
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      2600 non-null   int64
#  1   Период  2600 non-null   object
#  2   минут   2600 non-null   int64
# dtypes: int64(2), object(1)
# memory usage: 61.1+ KB

# %% [markdown]
# Датафрейм `market_time` состоит из `2600` строк и `3` столбцов, пропусков нет, данные представлены целочисленными и строковыми значениями.

# %%
# просмотрим первые строки четвертого датафрейма
money.head()
# Out:
#        id  Прибыль
# 0  215348     0.98
# 1  215349     4.16
# 2  215350     3.13
# 3  215351     4.87
# 4  215352     4.21

# %%
# просмотрим общую информацию о датафрейме
money.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1300 entries, 0 to 1299
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   id       1300 non-null   int64
#  1   Прибыль  1300 non-null   float64
# dtypes: float64(1), int64(1)
# memory usage: 20.4 KB

# %% [markdown]
# Датафрейм `money` состоит из `1300` строк и `2` столбцов, пропусков нет, данные представлены целочисленными и вещественными значениями.

# %% [markdown]
# **Вывод**
#
# После первичного знакомства с предоставленными данными можно сделать вывод, что данные соответствуют описанию задачи. Отсутствие пропусков означает, что не придется их заполнять, дубликаты и аномалии рассмотрим позже.

# %% [markdown]
# ## Предобработка данных

# %% [markdown]
# Для начала переименуем названия столбцов, поскольку некоторые из них довольно громоздкие, содержат пробелы и заглавные буквы, это будет мешать в дальнейшей обработке. Для удобства заменим русские названия столбцов на английские.

# %%
# выведем названия столбцов первого датафрейма
market_file.columns
# Out:
# Index(['id', 'Покупательская активность', 'Тип сервиса', 'Разрешить сообщать',
#        'Маркет_актив_6_мес', 'Маркет_актив_тек_мес', 'Длительность',
#        'Акционные_покупки', 'Популярная_категория',
#        'Средний_просмотр_категорий_за_визит',
#        'Неоплаченные_продукты_штук_квартал', 'Ошибка_сервиса',
#        'Страниц_за_визит'],
#       dtype='object')

# %% [markdown]
# Теперь изменим названия столбцов в этом датафрейме.

# %%
column_mapping = {
    'Покупательская активность': 'customer_activity',
    'Тип сервиса': 'service_type',
    'Разрешить сообщать': 'allow_messages',
    'Маркет_актив_6_мес': 'market_act_6_mon',
    'Маркет_актив_тек_мес': 'market_act_cur_mon',
    'Длительность': 'duration',
    'Акционные_покупки': 'promo_purchases',
    'Популярная_категория': 'popular_category',  
    'Средний_просмотр_категорий_за_визит': 'avg_cat_per_visit',
    'Неоплаченные_продукты_штук_квартал': 'unpaid_pcs_per_quar',
    'Ошибка_сервиса': 'service_error',
    'Страниц_за_визит': 'pgs_per_visit'
}

market_file.rename(columns=column_mapping, inplace=True)

# %%
# проверим, что получилось
market_file.sample(5)
# Out:
#           id customer_activity service_type allow_messages  market_act_6_mon  \
# 889   216237   Прежний уровень     стандарт             да               4.1
# 1000  216348   Прежний уровень     стандарт             да               3.9
# 492   215840         Снизилась     стандарт             да               3.9
# 86    215434         Снизилась     стандарт             да               3.9
# 1057  216405   Прежний уровень     стандарт             да               4.0
#
#       market_act_cur_mon  duration  promo_purchases  \
# 889                    4       551             0.21
# 1000                   5       356             0.28
# 492                    5       869             0.24
# 86                     4       674             0.21
# 1057                   4       436             0.21
#
#                           popular_category  avg_cat_per_visit  \
# 889   Мелкая бытовая техника и электроника                  4
# ...

# %%
# выведем названия столбцов второго датафрейма
market_money.columns
# Out:
# Index(['id', 'Период', 'Выручка'], dtype='object')

# %% [markdown]
# Изменим названия столбцов этого датафрейма.

# %%
column_mapping = {
    'Период': 'period',
    'Выручка': 'revenue'
}

market_money.rename(columns=column_mapping, inplace=True)

# %%
# проверим, что получилось
market_money.sample(5)
# Out:
#           id               period  revenue
# 3149  216397  препредыдущий_месяц   4471.0
# 3633  216559        текущий_месяц   4165.6
# 3196  216413        текущий_месяц   6254.4
# 1548  215864     предыдущий_месяц   4978.0
# 1701  215915  препредыдущий_месяц   4386.0

# %%
# выведем названия столбцов третьего датафрейма
market_time.columns
# Out:
# Index(['id', 'Период', 'минут'], dtype='object')

# %% [markdown]
# Изменим названия столбцов этого датафрейма.

# %%
column_mapping = {
    'Период': 'period',
    'минут': 'minutes'
}

market_time.rename(columns=column_mapping, inplace=True)

# %%
# проверим, что получилось
market_time.sample(5)
# Out:
#           id            period  minutes
# 1951  216323  предыдцщий_месяц       14
# 1381  216038     текущий_месяц       11
# 1801  216248  предыдцщий_месяц       12
# 892   215794     текущий_месяц       18
# 1066  215881  предыдцщий_месяц       17

# %%
# выведем названия столбцов четвертого датафрейма
money.columns
# Out:
# Index(['id', 'Прибыль'], dtype='object')

# %%
money.rename(columns={'Прибыль': 'revenue'}, inplace=True)

# %%
# проверим, что получилось
money.sample(5)
# Out:
#           id  revenue
# 731   216079     2.33
# 272   215620     5.04
# 608   215956     2.35
# 1065  216413     4.86
# 863   216211     2.86

# %% [markdown]
# С общим видом таблиц разобрались: изменили названия столбцов, привели их к общепринятому виду.
#
# Продолжим предобработку данных.
#
# Поскольку пропусков в данных нет, начнем поиск и обработку дубликатов и других аномалий.

# %% [markdown]
# Для начала проверим наличие уникальных строковых значений в датафреймах, чтобы выявить опечатки в данных.

# %%
# рассмотрим первый датафрейм
unique_values_customer_activity = market_file['customer_activity'].unique()
unique_values_service_type = market_file['service_type'].unique()
unique_values_allow_messages = market_file['allow_messages'].unique()
unique_values_popular_category = market_file['popular_category'].unique()

print("Датафрейм market_file")
print("------------------------------")
print("Уникальные значения в столбце customer_activity:")
print(unique_values_customer_activity)
print("------------------------------")
print("Уникальные значения в столбце service_type:")
print(unique_values_service_type)
print("------------------------------")
print("Уникальные значения в столбце allow_messages:")
print(unique_values_allow_messages)
print("------------------------------")
print("Уникальные значения в столбце popular_category:")
print(unique_values_popular_category)
# Out:
# Датафрейм market_file
# ------------------------------
# Уникальные значения в столбце customer_activity:
# ['Снизилась' 'Прежний уровень']
# ------------------------------
# Уникальные значения в столбце service_type:
# ['премиум' 'стандартт' 'стандарт']
# ------------------------------
# Уникальные значения в столбце allow_messages:
# ['да' 'нет']
# ------------------------------
# Уникальные значения в столбце popular_category:
# ['Товары для детей' 'Домашний текстиль' 'Косметика и аксесуары'
#  'Техника для красоты и здоровья' 'Кухонная посуда'
#  'Мелкая бытовая техника и электроника']

# %% [markdown]
# Итак, в столбце `service_type` датафрейма `market_file` обнаружилась опечатка в значении `стандарт`, исправим ее.

# %%
market_file['service_type'] = market_file['service_type'].replace('стандартт', 'стандарт')

# %%
# проверим, что получилось
market_file['service_type'].unique()
# Out:
# array(['премиум', 'стандарт'], dtype=object)

# %% [markdown]
# Обнаруженные опечатки в первом датафрейме исправлены.

# %%
# рассмотрим второй датафрейм
unique_values_period = market_money['period'].unique()

print("Датафрейм market_money")
print("------------------------------")
print("Уникальные значения в столбце period:")
print(unique_values_period)
# Out:
# Датафрейм market_money
# ------------------------------
# Уникальные значения в столбце period:
# ['препредыдущий_месяц' 'текущий_месяц' 'предыдущий_месяц']

# %% [markdown]
# Итак, в столбце `period` датафрейма `market_money` обнаружилась опечатка в значении `препредыдущий_месяц`, в слове пропущена буква `Д` (приставка "пред", пишем "преДпредыдущий"), исправим ошибку.

# %%
market_money['period'] = market_money['period'].replace('препредыдущий_месяц', 'предпредыдущий_месяц')

# %%
# проверим, что получилось
market_money['period'].unique()
# Out:
# array(['предпредыдущий_месяц', 'текущий_месяц', 'предыдущий_месяц'],
#       dtype=object)

# %% [markdown]
# Обнаруженные опечатки во втором датафрейме исправлены.

# %%
# рассмотрим третий датафрейм
unique_values_time_period = market_time['period'].unique()

print("Датафрейм market_time")
print("------------------------------")
print("Уникальные значения в столбце period:")
print(unique_values_time_period)
# Out:
# Датафрейм market_time
# ------------------------------
# Уникальные значения в столбце period:
# ['текущий_месяц' 'предыдцщий_месяц']

# %% [markdown]
# В столбце `period` датафрейма `market_time` мы видим опечатку в значении `предыдущий_месяц` (буква `ц` вместо буквы `у`), исправим ее.

# %%
market_time['period'] = market_time['period'].replace('предыдцщий_месяц', 'предыдущий_месяц')

# %%
# проверим, что получилось
market_time['period'].unique()
# Out:
# array(['текущий_месяц', 'предыдущий_месяц'], dtype=object)

# %% [markdown]
# Обнаруженные опечатки в третьем датафрейме исправлены.
#
# В четвертом датафрейме нет строковых значений, проверять данные на опечатки не будем.
#
# Проверим датафреймы на явные дубликаты.

# %%
market_file.duplicated().sum()
# Out:
# 0

# %%
market_money.duplicated().sum()
# Out:
# 0

# %%
market_time.duplicated().sum()
# Out:
# 0

# %%
money.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Явные дубликаты в предотсавленных датафреймах не обнаружены.

# %% [markdown]
# **Вывод**
#
# В ходе предобработки данных для удобства дальнейшей работы были заменены названия столбцов на английские, с нижними подчеркиваниями и без заглавных букв. Далее были обработаны опечатки в данных. Типы данных в таблицах соответствуют заявленным данным, поэтому изменения типов не требуются. Продолжим работу.

# %% [markdown]
# ## Исследовательский анализ данных

# %% [markdown]
# 1. **Проанализируем датафрейм `market_file`**

# %%
# просмотрим статистику датафрейма market_file
market_file.describe().T
# Out:
#                       count           mean         std       min        25%  \
# id                   1300.0  215997.500000  375.421985  215348.0  215672.75
# market_act_6_mon     1300.0       4.253769    1.014814       0.9       3.70
# market_act_cur_mon   1300.0       4.011538    0.696868       3.0       4.00
# duration             1300.0     601.898462  249.856289     110.0     405.50
# promo_purchases      1300.0       0.319808    0.249843       0.0       0.17
# avg_cat_per_visit    1300.0       3.270000    1.355350       1.0       2.00
# unpaid_pcs_per_quar  1300.0       2.840000    1.971451       0.0       1.00
# service_error        1300.0       4.185385    1.955298       0.0       3.00
# pgs_per_visit        1300.0       8.176923    3.978126       1.0       5.00
#
#                            50%        75%        max
# id                   215997.50  216322.25  216647.00
# market_act_6_mon          4.20       4.90       6.60
# ...

# %% [markdown]
# Из полученной статистики мы видим, что среднее **среднемесячное значение маркетинговых коммуникаций** (`market_act_6_mon`) компании, которое приходилось на покупателя за последние 6 месяцев, составляет `4.25` ед., среднее **количество маркетинговых коммуникаций в текущем месяце** (`market_act_cur_mon`) на покупателя — `4` ед.
#
# В **среднем** покупатели пользуются сайтом магазина **с момента регистрации** (`duration`) около 2х лет (`602` дня), **минимальное время** пользования сайтом с момента решистрации составляет около 4 мес (`110` дней), **максимальное время** — около 3х лет (`1079` дней).
#
# Средняя **среднемесячная доля покупок по акции от общего числа покупок за последние 6 месяцев** (`promo_purchases`) составляет `0.32`, есть пользователи, которые не пользуются акциями (минимальное значение данного показателя `0.0`), есть пользователи, которые практически все покупают по акции (максимальное значение данного показателя `0.99`).
#
# Среднее значение того, **сколько в среднем категорий покупатель просмотрел за визит в течение последнего месяца** (`avg_cat_per_visit`), составляет `3.27` ед., **минимальное значение** равно `1 категории`, **максимальное** — `6 категориям`.
#
# **Общее число неоплаченных товаров в корзине за последние 3 месяца** в среднем составляет `2.84` ед., минимальное значение — `0`, максимальное — `10`.
#
# **Число сбоев, которые коснулись покупателя во время посещения сайта**, в среднем составляет `4.2` ед., взаимодействие с сайтом может происходить без ошибок (**минимальное значение** — `0`), но иногда сбоев происходит достаточно много (**максимальное значение** — `9`).
#
# В среднем **среднее количество страниц, которые просмотрел покупатель за один визит на сайт за последние 3 месяца**, составляет `8.2`стр., **минимум** за визит покупатель смотрит `1 стр.`, а **максимум** — `20 стр.`

# %% [markdown]
# <u>**Построим графики**.</u>
#
# Для удобства построения графиков и избежания дублирования кода напишем функции: будем строить гистограммы и ящики с усами для количественных признаков и столбчатые диаграммы для категориальных признаков.

# %% [markdown]
# Для того, чтобы посмотреть на распределения признаков в разрезе целевого признака (снижения покупательской активности), разделим исходный датафрейм на два датафрейма: в одном останутся объекты со сниженной покупательской активностью (`df_decr`), во втором — с активностью на прежнем уровне (`df_stab`).

# %%
# датафрейм с данными, где покупательская активность снизилась
df_decr = market_file.query("customer_activity == 'Снизилась'")
df_decr.shape
# Out:
# (498, 13)

# %%
# датафрейм с данными, где покупательская активность на прежнем уровне
df_stab = market_file.query("customer_activity == 'Прежний уровень'")
df_stab.shape
# Out:
# (802, 13)

# %% [markdown]
# Датафрейм, в котором покупательская активность осталась на прежнем уровне, значительно больше второго, но в любом случае можно будет отследить общие тенденции.

# %%
# функция для построения гистограмм
def plot_histograms(df1, df2, column):
    plt.figure(figsize=(10, 6))

    # гистограмма для сниженной активности
    plt.subplot(1, 2, 2)
    plt.hist(df1[column], bins=10, alpha=0.5, color="blue")
    plt.title("Снижение активности")
    plt.xlabel(translations[column])
    plt.ylabel("Частота")

    # гистограмма для прежнего уровня активности
    plt.subplot(1, 2, 1)
    plt.hist(df2[column], bins=10, alpha=0.5, color="green")
    plt.title("Прежний уровень активности")
    plt.xlabel(translations[column])
    plt.ylabel("Частота")

    plt.tight_layout()
    plt.show()
    
# функция для построения ящиков с усами     
def plot_boxplots(df1, df2, column):
    plt.figure(figsize=(10, 6))

    # боксплот для сниженной активности
    plt.subplot(1, 2, 2)
    sns.boxplot(data=df1, y=column, color='blue')
    plt.title("Снижение активности")
    plt.ylabel(translations[column])

    # боксплот для прежнего уровня активности
    plt.subplot(1, 2, 1)
    sns.boxplot(data=df2, y=column, color='green')
    plt.title("Прежний уровень активности")
    plt.ylabel(translations[column])

    plt.tight_layout()
    plt.show()

# функция для построения столбчатых диаграмм
def plot_categorical_bar_chart(df1, df2, column):
    plt.figure(figsize=(15, 6))
    
    # столбчатая диаграмма для сниженной активности
    plt.subplot(1, 2, 2)
    if column == 'popular_category':
        colors = {
            'Товары для детей': 'blue',
            'Домашний текстиль': 'magenta',
            'Косметика и аксесуары': 'green',
            'Кухонная посуда': 'yellow',
            'Техника для красоты и здоровья': 'red',
            'Мелкая бытовая техника и электроника': 'pink'
        }
        df1_grouped = df1[column].value_counts(normalize=True)[
            ['Товары для детей', 'Домашний текстиль', 'Косметика и аксесуары', 
             'Кухонная посуда', 'Техника для красоты и здоровья', 'Мелкая бытовая техника и электроника']
        ]
        df1_grouped.plot(kind='bar', color=[colors[x] for x in df1_grouped.index])
        for i, v in enumerate(df1_grouped):
            plt.text(i, v, str(round(v * 100, 2)) + "%", ha='center', va='bottom')
    else:
        colors = ['blue', 'green']
        df1[column].value_counts(normalize=True).plot(kind='bar', color=colors)
        for i, v in enumerate(df1[column].value_counts(normalize=True)):
            plt.text(i, v, str(round(v * 100, 2)) + "%", ha='center', va='bottom')
    
    plt.title("Снижение активности")
    plt.xlabel(translations[column])
    plt.ylabel("Частота (%)")
    
    # столбчатая диаграмма для прежнего уровня активности
    plt.subplot(1, 2, 1)
    if column == 'popular_category':
        df2_grouped = df2[column].value_counts(normalize=True)[
            ['Товары для детей', 'Домашний текстиль', 'Косметика и аксесуары',
             'Кухонная посуда', 'Техника для красоты и здоровья', 'Мелкая бытовая техника и электроника']
        ]
        df2_grouped.plot(kind='bar', color=[colors[x] for x in df2_grouped.index])
        for i, v in enumerate(df2_grouped):
            plt.text(i, v, str(round(v * 100, 2)) + "%", ha='center', va='bottom')
    else:
        df2[column].value_counts(normalize=True).plot(kind='bar', color=colors)
        for i, v in enumerate(df2[column].value_counts(normalize=True)):
            plt.text(i, v, str(round(v * 100, 2)) + "%", ha='center', va='bottom')
    
    plt.title("Прежний уровень активности")
    plt.xlabel(translations[column])
    plt.ylabel("Частота (%)")

    plt.show()

# %% [markdown]
# Приступим к построению графиков.

# %%
# выберем столбцы датафреймов с количественными и категориальными признаками
market_file_num_columns = ['market_act_6_mon', 'market_act_cur_mon',
               'duration', 'promo_purchases', 'avg_cat_per_visit',
               'unpaid_pcs_per_quar', 'service_error', 'pgs_per_visit']
market_file_cat_columns = ['service_type', 'allow_messages', 'popular_category']

# %%
# напишем понятный для восприятия перевод для графиков
translations = {
    'market_act_6_mon': 'Среднее кол-во коммуникаций за 6 мес',
    'market_act_cur_mon': 'Кол-во коммуникаций за текущий мес',
    'duration': 'Дней с момента регистрации',
    'promo_purchases': 'Среднемесячная доля покупок по акции (6 мес)',
    'avg_cat_per_visit': 'Среднее кол-во категорий товаров за визит за мес',
    'unpaid_pcs_per_quar': 'Число неоплаченных товаров в корзине за 3 мес',
    'service_error': 'Число сбоев',
    'pgs_per_visit': 'Среднее кол-во страниц за визит за 3 мес',
    'service_type': 'Тип обслуживания', 
    'allow_messages': 'Разрешение на рассылку', 
    'popular_category': 'Популярная категория'
}

# %% [markdown]
# Рассмотрим **количественные признаки** с учетом целевого признака.

# %%
# построим гистограммы
for col in market_file_num_columns:
    plot_histograms(df_decr, df_stab, col)

# %%
# построим ящики с усами
for col in market_file_num_columns:
    plot_boxplots(df_decr, df_stab, col)

# %% [markdown]
# <u>**Промежуточные выводы по полученным графикам для количественных признаков**</u>
#
# И тот и другой сегмент покупателей (с прежней и сниженной покупательской активностью) зарегистрированы на сайте магазина примерно одно и то же время.
#
# Из полученных графиков мы видим, что **количество коммуникаций за текущий месяц** при снижении активности значительно возросло, то есть компания увеличила число рассылок, звонков, показов рекламы и прочего.
#
# Также стоит отметить, что **доля покупок по акции** значительно увеличилась при общем снижении активности у покупателей, с покупательской активностью на прежнем уровне доля покупок по акции за последние 6 мес. достаточно низкая.
#
# Покупатели с прежним уровнем активности просматривают значительно большее **количество категорий за визит** по сравнению с покупателями со сниженной активностью.
#
# **Количество неоплаченных товаров в корзинах** у покупателей со сниженной покупательской активностью больше, чем у другой категории покупателей, вероятно, они ожидают каких-то акций или скидок на отложенные товары.
#
# Покупательская активность не зависит от **количество сбоев в работе сайта**, поскольку видно, что при взаимодействии с сайтом у клиентов со сниженной покупательской активностью количество сбоев даже меньше, чем у тех, кто по-прежнему активно делает покупки.
#
# Стоит отметить, что покупаели с прежним уровнем активности просматривают гораздо большее **количество страниц сайта** магазина за визит. Возможно, они ищут что-то конкретное или же попросту не заинтересованы в дальнейшем просмотре.

# %% [markdown]
# Теперь рассмотрим **категориальные признаки** с учетом целевого признака.

# %%
# построим столбчатые диаграммы для категориальных признаков
for col in market_file_cat_columns:
    plot_categorical_bar_chart(df_decr, df_stab, col)

# %% [markdown]
# <u>**Выводы по полученным графикам для категориальных признаков**</u>
#
# **Тип обслуживания** покупателя и **разрешение на рассылку** не особенно влияют на снижение покупательской активности, а вот **популярные категории товаров** для покупки следует рассмотреть подробнее.
#
# Покупатели с прежним уровнем активности значительно больше покупали <u>технику для красоты и здоровья</u> и <u>мелкую бытовую технику и электронику</u>, покупки этих товаров при снижении покупательской активности значительно просела. Вероятнее всего, на эти категории товаров была объявлена акция, пользователи магазина активно покупали эти товары, а когда акция закончилась, активность покупателей снизилась.
#
# Покупка остальных категорий товаров при снижении покупательской активности немного подросла.

# %% [markdown]
# 2. **Проанализируем датафрейм `market_money`**

# %%
# просмотрим статистику датафрейма market_money
market_money.describe().T
# Out:
#           count           mean          std       min        25%       50%  \
# id       3900.0  215997.500000   375.325686  215348.0  215672.75  215997.5
# revenue  3900.0    5025.696051  1777.704104       0.0    4590.15    4957.5
#
#                75%       max
# id       216322.25  216647.0
# revenue    5363.00  106862.2

# %% [markdown]
# Данный датафрейм содержит один количественный признак, для которого нужно строить графики.
#
# После просмотра общей статистики есть подозрение, что максимальное значение выручки является выбросом, поскольку сильно отличается от медианы и третьего квартирля. Посмотрим на графики и удалим этот выброс.

# %%
# построим гистограмму
plt.figure(figsize=(10, 5))
sns.set()
sns.histplot(market_money['revenue'], kde=True, bins=1000, color='green')
plt.title('Распределение выручки')
plt.xlabel('Выручка')
plt.ylabel('Количество')
plt.show()

# %%
# построим ящик с усами
plt.figure(figsize=(10, 5))
sns.boxplot(x=market_money['revenue'], color='green')
plt.title(f'Ящик с усами для признака "Выручка"')
plt.xlabel('Выручка')
plt.show();

# %% [markdown]
# Да, на графиках видно, что это действительно выброс, удалим его.

# %%
market_money = market_money[(market_money['revenue'] <= 20000) & (market_money['revenue'] >= 3000)]

# %%
# проверим максимальное значение после удаления выброса
market_money['revenue'].max()
# Out:
# 7799.4

# %% [markdown]
# И еще раз построим график.

# %%
# построим ящик с усами
plt.figure(figsize=(10, 5))
sns.boxplot(x=market_money['revenue'], color='green')
plt.title(f'Ящик с усами для признака "Выручка"')
plt.xlabel('Выручка')
plt.xlim(0, 10000)
plt.show();

# %% [markdown]
# <u>**Вывод по датафрейму `market_money`**</u>
#
# В ходе изучения этого датафрейма был обнаружен выброс, который мог повлиять на дальнейшую работу с данными. Этот выброс был удален.

# %% [markdown]
# 3. **Проанализируем датафрейм `market_time`**

# %%
# просмотрим статистику датафрейма market_time
market_time.describe().T
# Out:
#           count           mean         std       min        25%       50%  \
# id       2600.0  215997.500000  375.349754  215348.0  215672.75  215997.5
# minutes  2600.0      13.336154    4.080198       4.0      10.00      13.0
#
#                75%       max
# id       216322.25  216647.0
# minutes      16.00      23.0

# %% [markdown]
# Данный датафрейм содержит один количественный признак, для которого нужно строить графики.

# %%
# построим гистограмму
plt.figure(figsize=(10, 5))
sns.set()
sns.histplot(market_time['minutes'], kde=True, bins=10, color='green')
plt.title('Распределение времени')
plt.xlabel('Время')
plt.ylabel('Количество')
plt.show();

# %%
# построим ящик с усами
plt.figure(figsize=(10, 5))
sns.boxplot(x=market_time['minutes'], color='green')
plt.title(f'Ящик с усами для признака "Время на сайте"')
plt.xlabel('Время')
plt.show();

# %% [markdown]
# <u>**Вывод по датафрейму `market_time`**</u>
#
# Время, проведенное пользователями на сайте, распределено нормально, выбросов нет.
#
# В **среднем** покупатели проводят на сайте примерно `13` минут, **максимум** — `23` минуты, **минимум** — `4` минуты.

# %% [markdown]
# 4. **Проанализируем датафрейм `money`**

# %%
# просмотрим статистику датафрейма money
money.describe().T
# Out:
#           count           mean         std        min        25%         50%  \
# id       1300.0  215997.500000  375.421985  215348.00  215672.75  215997.500
# revenue  1300.0       3.996631    1.013722       0.86       3.30       4.045
#
#                75%        max
# id       216322.25  216647.00
# revenue       4.67       7.43

# %% [markdown]
# Данный датафрейм содержит один количественный признак, для которого нужно строить графики.

# %%
# построим гистограмму
plt.figure(figsize=(10, 5))
sns.set()
sns.histplot(money['revenue'], kde=True, bins=10, color='green')
plt.title('Распределение прибыли')
plt.xlabel('Прибыль')
plt.ylabel('Количество')
plt.show();

# %%
# построим ящик с усами
plt.figure(figsize=(10, 5))
sns.boxplot(x=money['revenue'], color='green')
plt.title(f'Ящик с усами для признака "Прибыль"')
plt.xlabel('Прибыль')
plt.show();

# %% [markdown]
# <u>**Вывод по датафрейму `money`**</u>
#
# Значение прибыли распределено нормально, выбросы есть, но они соответствуют реальности, огромных значений нет.

# %% [markdown]
# **Общий вывод по исследовательскому анализу данных**
#
# Был проведен анализ количественных и качественных признаков во всех предоставленных датафреймах, изучено распределение данных с учетом целевого признака — покупательской активности. Во время проведения анализа обнаружены выбросы, которые были успешно удалены.
#
# В соответствии с заданием необходимо отобрать клиентов с покупательской активностью не менее трёх месяцев, то есть таких, которые что-либо покупали в этот период. Но, поскольку для этого нужно объединить таблицы, выполним эту операцию в следующем разделе.

# %% [markdown]
# ## Объединение таблиц

# %% [markdown]
# По заданию следует отобрать покупателей с активностью не менее трех месяцев, для этого нужно сделать так, чтобы данные о прибыли были за все три месяца.
#
# Поэтому выполним следующее:
# * создадим сводную таблицу по выручке за 3 месяца из датафрейма `market_money`,
# * создадим сводную таблицу по выручке за 2 месяца из датафрейма `market_time`,
# * объединим полученные сводные таблицы с датафреймом `market_file`,
# * удалим покупателей с пропусками в одной из колонок прибыли за 3 месяца.

# %%
# создадим сводную таблицу по выручке из датафрейма market_money
pivot_table_market_money = pd.pivot_table(market_money, index='id', values='revenue', columns='period')
pivot_table_market_money.head(5)
# Out:
# period  предпредыдущий_месяц  предыдущий_месяц  текущий_месяц
# id
# 215348                   NaN               NaN         3293.1
# 215349                4472.0            5216.0         4971.6
# 215350                4826.0            5457.5         5058.4
# 215351                4793.0            6158.0         6610.4
# 215352                4594.0            5807.5         5872.5

# %%
# переименую вновь получившиеся столбцы
pivot_table_market_money = pivot_table_market_money.rename(
    columns={
    'текущий_месяц': 'revenue_for_cur_month',
    'предыдущий_месяц': 'revenue_for_prev_month',
    'предпредыдущий_месяц': 'revenue_for_month_before_prev'
}
)
pivot_table_market_money.head(5)
# Out:
# period  revenue_for_month_before_prev  revenue_for_prev_month  \
# id
# 215348                            NaN                     NaN
# 215349                         4472.0                  5216.0
# 215350                         4826.0                  5457.5
# 215351                         4793.0                  6158.0
# 215352                         4594.0                  5807.5
#
# period  revenue_for_cur_month
# id
# 215348                 3293.1
# 215349                 4971.6
# 215350                 5058.4
# 215351                 6610.4
# 215352                 5872.5

# %%
# создадим сводную таблицу по выручке из датафрейма market_time
pivot_table_market_time = pd.pivot_table(market_time, index='id', values='minutes', columns='period')
pivot_table_market_time.head(5)
# Out:
# period  предыдущий_месяц  текущий_месяц
# id
# 215348                13             14
# 215349                12             10
# 215350                 8             13
# 215351                11             13
# 215352                 8             11

# %%
# переименую вновь получившиеся столбцы
pivot_table_market_time = pivot_table_market_time.rename(
    columns={
    'текущий_месяц': 'minutes_for_cur_month',
    'предыдущий_месяц': 'minutes_for_prev_month'
}
)
pivot_table_market_time.head(5)
# Out:
# period  minutes_for_prev_month  minutes_for_cur_month
# id
# 215348                      13                     14
# 215349                      12                     10
# 215350                       8                     13
# 215351                      11                     13
# 215352                       8                     11

# %%
# объединим полученные сводные таблицы с датафреймом market_file
merged_market_file = market_file.merge(pivot_table_market_money, on='id', how='left')

# %%
# проверим результат объединения
merged_market_file.sample(5)
# Out:
#           id customer_activity service_type allow_messages  market_act_6_mon  \
# 348   215696         Снизилась      премиум             да               3.4
# 1213  216561   Прежний уровень     стандарт             да               4.0
# 615   215963   Прежний уровень      премиум             да               4.6
# 102   215450         Снизилась      премиум             да               5.6
# 812   216160   Прежний уровень     стандарт             да               5.8
#
#       market_act_cur_mon  duration  promo_purchases  \
# 348                    3       384             0.98
# 1213                   4       842             0.28
# 615                    3       702             0.17
# 102                    4       857             0.36
# 812                    5       905             0.16
#
#                           popular_category  avg_cat_per_visit  \
# 348                        Кухонная посуда                  1
# ...

# %%
merged_market_file = merged_market_file.merge(pivot_table_market_time, on='id', how='left')

# %%
# проверим результат объединения
merged_market_file.sample(5)
# Out:
#           id customer_activity service_type allow_messages  market_act_6_mon  \
# 676   216024   Прежний уровень     стандарт             да               2.6
# 43    215391         Снизилась      премиум             да               3.5
# 212   215560         Снизилась     стандарт             да               3.9
# 120   215468         Снизилась     стандарт             да               2.7
# 1194  216542   Прежний уровень     стандарт            нет               3.4
#
#       market_act_cur_mon  duration  promo_purchases       popular_category  \
# 676                    4       389             0.17      Домашний текстиль
# 43                     3       754             0.30  Косметика и аксесуары
# 212                    4       589             0.35       Товары для детей
# 120                    4       515             0.94  Косметика и аксесуары
# 1194                   3       776             0.17       Товары для детей
#
# ...

# %%
# проверим размерность получившегося датафрейма (кол-во столбцов увеличилось на 5, как и предполагалось)
merged_market_file.shape
# Out:
# (1300, 18)

# %% [markdown]
# Объединение таблиц прошло успешно.
#
# Изучим получившийся датафрейм более подробно.

# %%
merged_market_file.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1300 entries, 0 to 1299
# Data columns (total 18 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   id                             1300 non-null   int64
#  1   customer_activity              1300 non-null   object
#  2   service_type                   1300 non-null   object
#  3   allow_messages                 1300 non-null   object
#  4   market_act_6_mon               1300 non-null   float64
#  5   market_act_cur_mon             1300 non-null   int64
#  6   duration                       1300 non-null   int64
#  7   promo_purchases                1300 non-null   float64
#  8   popular_category               1300 non-null   object
#  9   avg_cat_per_visit              1300 non-null   int64
#  10  unpaid_pcs_per_quar            1300 non-null   int64
#  11  service_error                  1300 non-null   int64
# ...

# %% [markdown]
# Как видим, в данных есть пропуски.

# %%
merged_market_file.isna().sum()
# Out:
# id                               0
# customer_activity                0
# service_type                     0
# allow_messages                   0
# market_act_6_mon                 0
# market_act_cur_mon               0
# duration                         0
# promo_purchases                  0
# popular_category                 0
# avg_cat_per_visit                0
# unpaid_pcs_per_quar              0
# service_error                    0
# pgs_per_visit                    0
# revenue_for_month_before_prev    3
# revenue_for_prev_month           7
# revenue_for_cur_month            3
# minutes_for_prev_month           0
# minutes_for_cur_month            0
# dtype: int64

# %% [markdown]
# Пропуски присутствуют в столбцах, отражающих прибыль за последние три месяца (`revenue_for_month_before_prev`, `renue_for_prev_month`, `revenue_for_cur_month`), поскольку это означает отсутствие покупательской активности за указанное время, соответствующие объекты можно смело удалить.

# %%
merged_market_file = merged_market_file.dropna()
merged_market_file.isna().sum()
# Out:
# id                               0
# customer_activity                0
# service_type                     0
# allow_messages                   0
# market_act_6_mon                 0
# market_act_cur_mon               0
# duration                         0
# promo_purchases                  0
# popular_category                 0
# avg_cat_per_visit                0
# unpaid_pcs_per_quar              0
# service_error                    0
# pgs_per_visit                    0
# revenue_for_month_before_prev    0
# revenue_for_prev_month           0
# revenue_for_cur_month            0
# minutes_for_prev_month           0
# minutes_for_cur_month            0
# dtype: int64

# %% [markdown]
# Пропуски удалены. Проверим наличие явных дубликатов.

# %%
merged_market_file.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Явных дубликатов не обнаружено.

# %% [markdown]
# **Вывод**
#
# В соответствии с поставленной задачей требовалось отобрать клиентов с покупательской активностью не менее трёх месяцев, то есть таких, которые что-либо покупали в этот период. При объединении таблиц данная цель была достигнута: мы получили полную таблицу, отражающую активность покупателей за указанный срок.

# %% [markdown]
# ## Корреляционный анализ

# %% [markdown]
# Матрица Phik широко используется для анализа корреляции между переменными в наборах данных. В данном случае мы будем использовать эту матрицу, поскольку она может учитывать корреляцию не только между количественными, но и между категориальными переменными. А нам эту нужно с целью понимания взаимосвязей в данных.

# %%
# создадим копию датафрейма без столбца идентификатора пользователя магазина для построения матрицы корреляции
merged_market_file_copy = merged_market_file.drop('id', axis=1)

# определим столбцы, которые имеют интервальные значения
interval_cols = ['market_act_6_mon', 'market_act_cur_mon',
                 'duration', 'promo_purchases',
                 'avg_cat_per_visit', 'unpaid_pcs_per_quar',
                 'service_error', 'pgs_per_visit',
                 'revenue_for_month_before_prev', 'revenue_for_prev_month',
                 'revenue_for_cur_month', 'minutes_for_prev_month', 'minutes_for_cur_month']

# расчет коэффициентов корреляции Phik
correlation_matrix = phik.phik_matrix(merged_market_file_copy, interval_cols=interval_cols)

# построение графика корреляции
plt.figure(figsize=(20, 15))
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm")

plt.title("Матрица корреляции (Phik)")
plt.show();

# %% [markdown]
# Как правило, о мультиколлинеарности говорят при значении коэффициента корреляции от `0.9` до `0.95` по модулю. Здесь таких значений мы не наблюдаем.
#
# Исходя из получившегося графика, мы видим ВЫСОКУЮ (`0.7—0.9` по шкале Чеддока) корреляцию между **прибылью за текущий месяц** (`revenue_for_cur_month`) и **прибылью за предыдущий месяц** (`revenue_for_prev_month`) — `0.85` и между **покупательской активностью** (`customer_activity`) и **количеством просмотренных страниц за визит** (`pgs_per_visit`) — `0.75`.
#
# Также наблюдается ЗАМЕТНАЯ (`0.5—0.7` по шкале Чеддока) корреляция наблюдается между **покупательской активностью** (`customer_activity`) и **временем в минутах, проведенном на сайте за предыдущий месяц** (`minutes_for_prev_month`) — `0.68`, между **покупательской активностью** (`customer_activity`) и **временем в минутах, проведенном на сайте за текущий месяц** (`minutes_for_cur_month`) — `0.58`, между **покупательской активностью** (`customer_activity`) и **средним количеством просмотренных категорий за визит за последний месяц** (`avg_cat_per_visit`) и **количеством маркетинговых коммуникаций компаниис покупателем за последние 6 месяцев** (`market_act_6_mon`) — `0.54`, между **покупательской активностью** (`customer_activity`) и **акционными покупками** (`promo_purchases`) — `0.51`, между **покупательской активностью** (`customer_activity`) и **выручкой за предпредыдущий месяц** (`revenue_for_month_before_prev`) и **количеством неоплаченных товаров в корзине за последние 3 месяца** (`unpaid_pcs_per_quar`) — `0.5`.
#
# Остальные признаки коррелируют умеренно или слабо (по шкале Чеддока), есть случаи отсутствия корреляции.

# %% [markdown]
# ## Использование пайплайнов

# %% [markdown]
# Поскольку целевой признак **покупательская активность** (`customer_activity`) у нас является категориальным, для начала перед разделением данных заменим доступные значения следующим образом: `Снизилась` на `1`, `Прежний уровень` на `0`.

# %%
merged_market_file['customer_activity'] = (
    merged_market_file['customer_activity'].apply(lambda x: 1 if x == 'Снизилась' else (0 if x == 'Прежний уровень' else x)))

# %% [markdown]
# Убедимся, что замена выполнена успешно.

# %%
merged_market_file.sample(3)
# Out:
#          id  customer_activity service_type allow_messages  market_act_6_mon  \
# 361  215709                  1     стандарт            нет               4.6
# 269  215617                  1     стандарт             да               0.9
# 21   215369                  1     стандарт            нет               2.7
#
#      market_act_cur_mon  duration  promo_purchases   popular_category  \
# 361                   5       352             0.89  Домашний текстиль
# 269                   4       728             0.90  Домашний текстиль
# 21                    4       607             0.21   Товары для детей
#
#      avg_cat_per_visit  unpaid_pcs_per_quar  service_error  pgs_per_visit  \
# 361                  1                    3              2              6
# 269                  2                    3              2              4
# 21                   2                    2              3              4
#
#      revenue_for_month_before_prev  revenue_for_prev_month  \
# ...

# %% [markdown]
# Приступим к созданию пайплайна.
#
# Для выполнения поставленной задачи будем использовать **метрику ROC-AUC** (Receiver Operating Characteristic - Area Under the Curve) — это метрика оценивает способность модели различать объекты классов. Она измеряет площадь под ROC-кривой, которая показывает отношение между долей верно классифицированных положительных и долей ложноположительных результатов при изменении порогового значения. Чем выше значение ROC-AUC, тем лучше модель проводит различие между положительным и отрицательным классами.

# %%
# разделим данные на обучающую (80%) и тестовую выборки (20%), зададим стратификацию, чтобы сохраненить баланс классов
# определим random_state
RANDOM_STATE = 42
TEST_SIZE = 0.2

X_train, X_test, y_train, y_test = train_test_split(
    merged_market_file.drop(['id','customer_activity'], axis=1),
    merged_market_file['customer_activity'],
    test_size = TEST_SIZE, 
    random_state = RANDOM_STATE,
    stratify = merged_market_file['customer_activity']
)

# проверим размер получившихся выборок
print(X_train.shape, X_test.shape)
# Out:
# (1032, 16) (258, 16)

# %%
# создадим списки с названиями признаков
ohe_columns = ['popular_category']
ord_columns = ['service_type', 'allow_messages']
num_columns = [
    'market_act_6_mon', 'market_act_cur_mon',
    'duration', 'promo_purchases', 'avg_cat_per_visit',
    'unpaid_pcs_per_quar', 'service_error', 'pgs_per_visit',
    'revenue_for_month_before_prev', 'revenue_for_prev_month',
    'revenue_for_cur_month', 'minutes_for_prev_month',
    'minutes_for_cur_month'
]

# %%
# у нас нет пропусков в данных, поэтому SimpleImputer использовать не будем

# пайплайн для кодирования категориальных признаков
ohe_pipe = Pipeline(
    [('ohe', OneHotEncoder(drop='first', handle_unknown='error', sparse_output=False))]
)

# пайплайн для кодирования порядковых признаков
ord_pipe = Pipeline(
    [('ord', OrdinalEncoder(
        categories=[
            ['стандарт', 'премиум'],
            ['нет', 'да'],
        ],
        handle_unknown='use_encoded_value', unknown_value=np.nan
    ))]
)

# пайплайн для масштабирования количественных признаков
num_pipe = Pipeline(
    [('scaler', StandardScaler())]
)

# объединяем все пайплайны с помощью ColumnTransformer
data_preprocessor = ColumnTransformer([
    ('ohe', ohe_pipe, ohe_columns),
    ('ord', ord_pipe, ord_columns),
    ('num', num_pipe, num_columns)
], remainder='passthrough')

# итоговый пайплайн
pipe_final = Pipeline([
    ('preprocessor', data_preprocessor),
    ('model', DecisionTreeClassifier(random_state=RANDOM_STATE))
])

# %%
param_grid = [
    # словарь для модели KNeighborsClassifier()
    {
        'model': [KNeighborsClassifier()],
        'model__n_neighbors': range(3, 8),
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), 'passthrough']
    },
    
    # словарь для модели DecisionTreeClassifier()
    {
        'model': [DecisionTreeClassifier(random_state=RANDOM_STATE)],
        'model__max_depth': range(1, 10),
        'model__min_samples_split': range(2, 10),
        'model__min_samples_leaf': range(2, 10),
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), 'passthrough']    
    },
    
    # словарь для модели LogisticRegression()
    {
        'model': [LogisticRegression(random_state=RANDOM_STATE, solver='liblinear', penalty='l1')],
        'model__C': range(1, 7), 
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), 'passthrough']
    },
    
    # словарь для модели SVC()
    {
        'model': [SVC(random_state=RANDOM_STATE, probability=True)],
        'model__C': [0.01, 0.1, 1, 10],
        'model__kernel': ['linear', 'rbf', 'sigmoid', 'poly'], 
        'model__gamma': [0.01, 0.1, 1, 10],
        'model__degree': [2, 3, 4],
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), 'passthrough'] 
    }
]

# %%
random_search = RandomizedSearchCV(
    pipe_final,
    param_grid,
    cv=5,
    scoring='roc_auc',
    n_jobs=-1,
    random_state=RANDOM_STATE)

random_search.fit(X_train, y_train)

print('Лучшая модель и ее параметры:\n\n', random_search.best_estimator_)
print('Метрика лучшей модели на тренировочной выборке:', random_search.best_score_)

probabilities = random_search.predict_proba(X_test)
probabilities_one = probabilities[:, 1]
print('Площадь ROC-кривой:', roc_auc_score(y_test, probabilities_one))
# Out:
# Лучшая модель и ее параметры:
#
#  Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('ohe',
#                                                   Pipeline(steps=[('ohe',
#                                                                    OneHotEncoder(drop='first',
#                                                                                  sparse_output=False))]),
#                                                   ['popular_category']),
#                                                  ('ord',
#                                                   Pipeline(steps=[('ord',
#                                                                    OrdinalEncoder(categories=[['стандарт',
#                                                                                                'премиум'],
# ...

# %% [markdown]
# **Вывод**
#
# В результате выбрана **лучшая модель — SVC** (Support Vector Classifier — метод опорных векторов) со следующими параметрами:
#
# - `C` (параметр регуляризации) равен `1`,
# - `degree` (степень полиномиальной функции ядра) равна `4`,
# - `gamma` (коэффициент влияния) равен `1`,
# - `kernel` (ядро) задано `linear` (линейное),
# - `probability`(дополнительные вычисления для оценки вероятностей принадлежности к каждому классу) определено `True`,
# - `random_state` равно `42`.
#
# Метрика лучшей модели на тренировочной выборке составляет с округлением `0.9`, что говорит о высокой точности работы модели на обучающих данных, что в целом вполне ожидаемо, поскольку это тренировочные данные.
#
# Значение **площади под ROC-кривой (ROC-AUC)** равное с округлением `0.9` означает, что модель достигла достаточно хороших результатов в классификации.
#
# ROC-AUC является метрикой, которая измеряет качество классификационной модели, основываясь на ее способности различать объекты двух классов. Значение ROC-AUC находится в диапазоне от 0 до 1, где 1 означает идеальное разделение классов, а 0.5 означает случайное угадывание. Таким образом, чем выше значение ROC-AUC, тем лучше модель выполняет классификацию. У нас получилось значение, достаточно близкое к единице.

# %% [markdown]
# ## Анализ важности признаков

# %% [markdown]
# Оценим важность признаков для лучшей модели и построим график важности с помощью метода SHAP.
#
# Столбчатая диаграмма `shap.plots.bar` отражает общий вклад признаков в прогнозы модели. Она показывает средние SHAP-значения признака по всем наблюдениям. Для расчета средних берут значения Шепли по модулю, чтобы положительные и отрицательные значения не сводили друг друга к нулю.

# %%
# преобразуем данные обучающей выборки
X_train = pipe_final.named_steps['preprocessor'].fit_transform(X_train)

# создадим объект explainer
explainer = shap.Explainer(random_search.best_estimator_.named_steps['model'], X_train)

# преобразуем данные тестовой выборки
X_test = pipe_final.named_steps['preprocessor'].transform(X_test)

# получим имена признаков
feature_names = pipe_final.named_steps['preprocessor'].get_feature_names_out()

# создадим датафрейм для тестовых данных с именами признаков
X_test = pd.DataFrame(X_test, columns=feature_names)

# посчитаем значения SHAP для тестовых данных
shap_values = explainer(X_test)

# визуализируем значения SHAP в виде столбчатой диаграммы
shap.plots.bar(shap_values)

# %%
# визуализируем значения SHAP в виде графика "осиное гнездо"
shap.plots.beeswarm(shap_values)

# %% [markdown]
# **Вывод**
#
# Сильнее всего на целевой признак влияют влияют следующие признаки: количество страниц за визит, время, проведенное на сайте в предыдущем месяце, среднемесячная доля покупок по акции от общего числа покупок за последние 6 месяцев, время, проведенное на сайте в текущем месяце, среднее количество категорий, просмотренных покупателем за визит в течение последнего месяца.
#
# Выручка за текущий и предыдущий месяц, количество неоплаченных товаров в корзине за последние 3 месяца и среднемесячное значение маркетинговых коммуникаций компании, которое приходилось на покупателя за последние 6 месяцев не так значимы.
#
# Тип обслуживани, разрешение рассылки, маркетинговые коммуникации за текущий месяц, популярная категория товара и количество ошибок сервиса являются малозначимыми признаками, которые практически не учитываются моделью при принятии решения.

# %% [markdown]
# <u>**Данные наблюдения можно использовать для принятия следующих бизнес-решений**:</u>
#
# 1. Улучшить навигацию и пользовательский опыт на сайте, чтобы посетители могли легко находить интересующую их информацию или продукты.
#
# 2. Продолжить стимулировать покупателей акциями и специальными предложениями, чтобы увеличить уровень участия в акциях и общее количество покупок.
#
# 3. Обратить внимание на текущий месяц и попробовать предложить временные акции, скидки или новые продукты, чтобы удержать или увеличить уровень активности покупателей.
#
# 4. Обеспечить четкую структуру категорий товаров на сайте и убедиться, что покупатели легко могут переходить между различными категориями или разделами продуктов.
#
# 5. Стараться удерживать посетителей на сайте и повысить их вовлеченность путем предоставления интересного и полезного контента, акций или персонифицированных рекомендаций.
#
# Важно помнить, что эти рекомендации основываются на модели и анализе данных. Чтобы полностью оптимизировать свой Интернет-магазин, рекомендуется учитывать и другие факторы, такие как отзывы клиентов, конкурентное окружение и тенденции рынка.

# %% [markdown]
# ## Сегментация покупателей

# %% [markdown]
# Выполним сегментацию покупателей.
#
# Мне интересно рассмотреть группу клиентов Интернет-магазина с высокой долей покупок по акции и наиболее высокой прибыльностью, но с высокой вероятностью снижения покупательской активности.
#
# Для отбора таких клиентов создадим новый датафрейм `customer_segmentation`, который является копией датафрейма `money` (данные о среднемесячной прибыли от покупателя за последние 3 месяца), в котором мы оставим только тех покупателей, которые присутствуют в объединенном датафрейме `merged_market_file`.

# %%
customer_segmentation = money[money['id'].isin(merged_market_file['id'])].copy()

# %% [markdown]
# Теперь с помощью лучшей обученной модели, выбранной с помощью `random_search`, предскажем вероятность снижения активности покупателей и добавим полученные значения в новый столбец `expect_activity_decrease` датафрейма `customer_segmentation`.

# %%
proba = random_search.predict_proba(merged_market_file.drop(['customer_activity', 'id'], axis=1))
customer_segmentation['expect_activity_decrease'] = proba[:, 0]

# %%
customer_segmentation['id'].nunique()
# Out:
# 1290

# %% [markdown]
# Теперь в датафрейм `customer_segmentation` добавим столбцы `promo_purchases`, `customer_activity` и `popular_category` из датафрейма `merged_market_file` по идентификатору клиента магазина.

# %%
customer_segmentation = customer_segmentation.merge(merged_market_file[
    ['id', 'promo_purchases', 'customer_activity', 'popular_category']
], on='id', how='left')

# %% [markdown]
# Выведем несколько строк получившегося датафрейма.

# %%
customer_segmentation.head()
# Out:
#        id  revenue  expect_activity_decrease  promo_purchases  \
# 0  215349     4.16                  0.061891             0.75
# 1  215350     3.13                  0.482200             0.14
# 2  215351     4.87                  0.168954             0.99
# 3  215352     4.21                  0.027168             0.94
# 4  215353     3.95                  0.376906             0.26
#
#    customer_activity   popular_category
# 0                  1   Товары для детей
# 1                  1  Домашний текстиль
# 2                  1   Товары для детей
# 3                  1   Товары для детей
# 4                  1  Домашний текстиль

# %%
customer_segmentation.describe()
# Out:
#                   id      revenue  expect_activity_decrease  promo_purchases  \
# count    1290.000000  1290.000000               1290.000000      1290.000000
# mean   216000.325581     3.998977                  0.617660         0.320101
# std       373.782053     1.010638                  0.362178         0.249698
# min    215349.000000     0.860000                  0.000008         0.110000
# 25%    215678.250000     3.300000                  0.196317         0.170000
# 50%    216000.500000     4.050000                  0.785304         0.240000
# 75%    216323.750000     4.670000                  0.924439         0.300000
# max    216647.000000     7.430000                  0.996969         0.990000
#
#        customer_activity
# count        1290.000000
# mean            0.379845
# std             0.485536
# min             0.000000
# 25%             0.000000
# 50%             0.000000
# 75%             1.000000
# max             1.000000

# %%
customer_segmentation.shape
# Out:
# (1290, 6)

# %% [markdown]
# Построим диаграмму рассеяния, чтобы проанализировать взаимосвясь вероятности снижения активности покупателя, прибыли, которую он приносит Интернет-магазину, и долей приобретаемых им товаров по акции.

# %%
# создаем цветовую карту для значения promo_purchases
cmap = plt.get_cmap('coolwarm')

# создаем массив цветов в зависимости от значения promo_purchases
colors = [cmap(x) for x in np.clip(customer_segmentation['promo_purchases'], 0, 1)]

plt.figure(figsize=(15, 5))
plt.scatter(x='expect_activity_decrease', y='revenue', data=customer_segmentation,
            c=colors, alpha=0.5)
plt.colorbar(label='Покупки по акции')  # добавим цветовую шкалу
plt.title('Анализ взаимосвязи вероятности снижения активности, прибыли от покупателя и долей приобретаемых акционных товаров')
plt.xlabel('Вероятность снижения покупательской активности')
plt.ylabel('Прибыль')
plt.show()

# %% [markdown]
# Построим также матрицу корреляции.

# %%
correlation_matrix = customer_segmentation.drop(['customer_activity'], axis=1).corr(method='spearman')
sns.heatmap(correlation_matrix, annot=True, cmap='Greens')
plt.yticks()
plt.title(f'Матрица корреляции')
plt.show()
# Out:
# The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.

# %% [markdown]
# Итак, между вероятностью снижения покупательской активности и долей акционных покупок существует заметная положительная корреляция (`0.58`), что может означать, что при снижении количества акций на продаваемые товары, покупательская активность пользователей снижается, и наоборот.

# %% [markdown]
# Поскольку данное наблюдение относится не ко всем покупателям, а к какому-то конкретному классу, посмотрим какие покупки совершались и какой уровень покупательской активности наблюдался.

# %% [markdown]
# Разделим датафрейм `customer_segmentation`на два датафрейма: со сниженной покупательской активностью и с покупательской активностью на прежнем уровне.

# %%
# датафрейм с данными, где покупательская активность снизилась
customer_segm_1 = customer_segmentation.query("customer_activity == 1")
customer_segm_1.shape
# Out:
# (490, 6)

# %%
customer_segm_1.head()
# Out:
#        id  revenue  expect_activity_decrease  promo_purchases  \
# 0  215349     4.16                  0.061891             0.75
# 1  215350     3.13                  0.482200             0.14
# 2  215351     4.87                  0.168954             0.99
# 3  215352     4.21                  0.027168             0.94
# 4  215353     3.95                  0.376906             0.26
#
#    customer_activity   popular_category
# 0                  1   Товары для детей
# 1                  1  Домашний текстиль
# 2                  1   Товары для детей
# 3                  1   Товары для детей
# 4                  1  Домашний текстиль

# %%
# датафрейм с данными, где покупательская осталась на прежнем уровне
customer_segm_0 = customer_segmentation.query("customer_activity == 0")
customer_segm_0.shape
# Out:
# (800, 6)

# %%
customer_segm_0.head()
# Out:
#          id  revenue  expect_activity_decrease  promo_purchases  \
# 392  215748     4.11                  0.774118             0.18
# 393  215749     6.17                  0.963641             0.30
# 394  215750     2.39                  0.873493             0.21
# 395  215751     2.60                  0.891236             0.17
# 396  215752     4.06                  0.540301             0.30
#
#      customer_activity                      popular_category
# 392                  0                       Кухонная посуда
# 393                  0        Техника для красоты и здоровья
# 394                  0                      Товары для детей
# 395                  0        Техника для красоты и здоровья
# 396                  0  Мелкая бытовая техника и электроника

# %% [markdown]
# Мы получили два датафрейма. Построим круговые диаграммы, чтобы просмотреть категории товаров, которые приобретались отобранной группой пользователей при снижении и при сохранении покупательской активности.

# %%
# создадим словарь с соответствием категорий и цветов
category_colors = {
    'Домашний текстиль': 'skyblue',
    'Товары для детей': 'salmon',
    'Техника для красоты и здоровья': 'lightgreen',
    'Кухонная посуда': 'orange',
    'Косметика и аксесуары': 'pink',
    'Мелкая бытовая техника и электроника': 'brown'
}

fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(20, 5))

# категории товаров на прежнем уровне покупательской активности
customer_segm_0_popular_categories = customer_segm_0['popular_category'].value_counts()

# получение цветов для каждой категории
colors_segm_0 = [category_colors.get(category, 'gray') for category in customer_segm_0_popular_categories.index]

# построение круговой диаграммы для этого датафрейма
axes[0].pie(customer_segm_0_popular_categories, 
            labels=customer_segm_0_popular_categories.index, autopct='%1.1f%%', colors=colors_segm_0)
axes[0].set_title('Прежний уровень активности', fontweight='bold')

# категории товаров на сниженном уровне покупательской активности
customer_segm_1_popular_categories = customer_segm_1['popular_category'].value_counts()

# получение цветов для каждой категории
colors_segm_1 = [category_colors.get(category, 'gray') for category in customer_segm_1_popular_categories.index]

# построение круговой диаграммы для этого датафрейма
axes[1].pie(customer_segm_1_popular_categories, 
            labels=customer_segm_1_popular_categories.index, autopct='%1.1f%%', colors=colors_segm_1)
axes[1].set_title('Снижение активности', fontweight='bold')

plt.show()

# %% [markdown]
# **Вывод:**
#
# В отобранной группе пользователей прослеживается следующая тенденция покупок: покупка товаров категорий "Мелкая бытовая техника и электроника" и "Техника для красоты и здоровья" сильно просела — с `18.4%` до `5.5%` и с `16.4%` до `9.8%` соответственно.
#
# Остальные категории товаров, судя по графикам, несколько выросли в продаже, но, если учесть, что количество объектов в получившихся датафреймах разное, вероятно, они остались примерно на том же уровне.
#
# Отсюда делаем вывод, что в Интернет-магазине, вероятнее всего, была объявлена акция на товары категорий "Мелкая бытовая техника и электроника" и "Техника для красоты и здоровья", это привлекло клиентов, но они не стали постоянными клиентами магазина, поэтому продажи снизились.

# %% [markdown]
# Теперь отберем целевую группу **пользователей со среднемесячной прибылью**, полученной магазином за последние 3 месяца, `больше 4` (среднее значение прибыли) и высокой **вероятностью снижения покупательской активности** — `более 0.7`. А затем посмотрим, кто из них предпочитает пользоваться **акциями на товары при покупке**, и кто покупает вне зависимости от проводимых акций.

# %%
customer_segmentation['selection'] = 'to_del' 
select = ((customer_segmentation['revenue'] > 4) & 
          (customer_segmentation['expect_activity_decrease'] > 0.7)) #& 
customer_segmentation.loc[select, 'selection'] = 'target_customer'
customer_segmentation = customer_segmentation[customer_segmentation['selection'] != 'to_del']
target_customers_research = customer_segmentation.merge(merged_market_file.drop(['promo_purchases',
                                                                                'customer_activity',
                                                                                'popular_category'], axis=1),
                                                         on='id', how='inner')

# %%
target_customers_research.shape
# Out:
# (385, 21)

# %%
target_customers_research.head()
# Out:
#        id  revenue  expect_activity_decrease  promo_purchases  \
# 0  215355     5.26                  0.749179             0.17
# 1  215675     4.31                  0.746274             0.16
# 2  215676     5.10                  0.754439             0.17
# 3  215678     4.67                  0.874923             0.11
# 4  215681     4.79                  0.954714             0.21
#
#    customer_activity                popular_category        selection  \
# 0                  1                Товары для детей  target_customer
# 1                  1                Товары для детей  target_customer
# 2                  1               Домашний текстиль  target_customer
# 3                  1  Техника для красоты и здоровья  target_customer
# 4                  1                Товары для детей  target_customer
#
#   service_type allow_messages  market_act_6_mon  market_act_cur_mon  duration  \
# 0     стандарт            нет               4.7                   4       284
# ...

# %%
target_customers_research.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 385 entries, 0 to 384
# Data columns (total 21 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   id                             385 non-null    int64
#  1   revenue                        385 non-null    float64
#  2   expect_activity_decrease       385 non-null    float64
#  3   promo_purchases                385 non-null    float64
#  4   customer_activity              385 non-null    int64
#  5   popular_category               385 non-null    object
#  6   selection                      385 non-null    object
#  7   service_type                   385 non-null    object
#  8   allow_messages                 385 non-null    object
#  9   market_act_6_mon               385 non-null    float64
#  10  market_act_cur_mon             385 non-null    int64
#  11  duration                       385 non-null    int64
# ...

# %% [markdown]
# Итак, датафрейм `target_customers_research`содержит информацию о целевой группе покупателей, т. е. о тех, кто принес за последние три месяца среднемесячную прибыль больше 4 и у кого высокая вероятность снижения покупательской активности — более 0.7.

# %% [markdown]
# Для графического анализа данных отобранных пользователей выберем важные количественные и категориальные признаки.

# %%
cat_features = ['service_type', 'allow_messages', 'popular_category']
num_features = ['customer_activity', 'avg_cat_per_visit', 'pgs_per_visit', 'minutes_for_cur_month',
                'minutes_for_prev_month', 'unpaid_pcs_per_quar', 'promo_purchases']

# %%
# напишем понятный для восприятия перевод для графиков
translate = {
    'service_type': 'Тип обслуживания',
    'allow_messages': 'Разрешение на рассылку',
    'popular_category': 'Популярная категория покупок'
}

# %%
# напишем понятный для восприятия перевод для графиков
translations = {
    'avg_cat_per_visit': 'Среднее кол-во категорий товаров за визит за мес',    
    'pgs_per_visit': 'Среднее кол-во страниц за визит за 3 мес',
    'minutes_for_cur_month': 'Время, проведенное на сайте в текущем месяце',
    'minutes_for_prev_month': 'Время, проведенное на сайте в предыдущем месяце', 
    'unpaid_pcs_per_quar': 'Число неоплаченных товаров в корзине за 3 мес',
    'promo_purchases': 'Доля покупок по акции',
    'customer_activity': 'Покупательская активность'
}

# %% [markdown]
# Напишем функции для построения графиков.

# %%
# функция для построения круговой диаграммы
def plot_pie_chart(data, column, translations):
    value_counts = data[column].value_counts()
    plt.figure(figsize=(5, 5))
    plt.pie(value_counts, labels=value_counts.index, autopct='%1.1f%%')
    plt.title(f'Распределение признака "{translations[column]}"')
    plt.show()
    
# функция для построения гистограммы
def create_histogram(data, column, translations):
    plt.figure(figsize=(15, 5))
    sns.set()
    sns.histplot(data=data, x=column, kde=True, bins=15, color='green')
    plt.title(f'Плотность распределения признака "{translations[column]}"')
    plt.xlabel(column, fontsize=14)
    plt.ylabel('Частота', fontsize=14)
    plt.show()

# %% [markdown]
# Построим графики.

# %%
# вызовем функцию и построим графики для количественных признаков
for num in num_features:
    create_histogram(target_customers_research, num, translations)

# %% [markdown]
# Мы видим, что в отобранной категории покупателей со сниженной покупательской активностью пракитчески в 7 раз меньше чем тех, чья покупательская активность осталась на прежнем уровне.
#
# За один видит они просматривают `3—5 категорий` товаров, просматривают `8—12 страниц` за визит, проводят на сайте в срежнем `11—17 минут` как в текущем, так и в предыдущем месяце, имеют в среднем `1-3 неоплаченных товара` в корзине за квартал, большая часть покупателей отобранной группы пользуются акциями, в подавляющем большинстве `доля покупок по акции меньше 0.5`.

# %%
# вызовем функцию и построим графики для категориальных признаков
for cat in cat_features:
    plot_pie_chart(target_customers_research, cat, translate)

# %% [markdown]
# 3/4 представителей данной группы принадлежит к стандартному типу обслуживания, примерно аналогичная доля пользователей разрешили компании осуществлять рассылку дополнительных предложений. Самой популярной категорией товаров у этой группы пользователей являются товары для детей (21.6 %) и домашний тестиль (21 %), остальные категории товаров представлены в меньшем процентном соотношении.

# %% [markdown]
# Построим круговые диаграммы для того, чтобы посмотреть, какие группы товаров эти пользователи покупали по акционным ценам, и когда —при прежнем уровне активности или при сниженном.

# %% [markdown]
# Для изучения связи покупательской активности и покупок по акции снова создадим два отдельных датафрейма из датафрейма `target_customers_research`.

# %%
# датафрейм с данными, где покупательская активность прежняя
prev_act_customers = target_customers_research.query("customer_activity == 0")
prev_act_customers.shape
# Out:
# (343, 21)

# %%
# датафрейм с данными, где покупательская активность снизилась
decr_act_customers = target_customers_research.query("customer_activity == 1")
decr_act_customers.shape
# Out:
# (42, 21)

# %% [markdown]
# Как мы видим, в отобранной категории не так много покупателей, чья покупательская активность снизилась. Посмотрим, какие категори товаров они приобретали.

# %%
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(20, 10))

# фильтрация данных по условию promo_purchases > 0.5 для прежнего уровня активности
prev_act_high_promo = prev_act_customers[prev_act_customers['promo_purchases'] > 0.5]
prev_act_low_promo = prev_act_customers[prev_act_customers['promo_purchases'] < 0.5]

# получение категорий товаров и их количества для прежнего уровня активности с высокой акционной долей
prev_act_high_promo_categories = prev_act_high_promo['popular_category'].value_counts()
colors_0 = [category_colors.get(category, 'gray') for category in prev_act_high_promo_categories.index]
if prev_act_high_promo_categories.empty:
    axes[0, 0].text(0.5, 0.5, "Нет таких объектов", ha='center', va='center', fontsize=12)
else:
    axes[0, 0].pie(prev_act_high_promo_categories, labels=prev_act_high_promo_categories.index, 
                   autopct='%1.1f%%', colors=colors_0, normalize=True)
    axes[0, 0].set_title('Прежний уровень активности: высокая акционная доля', fontweight='bold')

# получение категорий товаров и их количества для прежнего уровня активности с низкой акционной долей
prev_act_low_promo_categories = prev_act_low_promo['popular_category'].value_counts()
colors_1 = [category_colors.get(category, 'gray') for category in prev_act_low_promo_categories.index]
if prev_act_low_promo_categories.empty:
    axes[1, 0].text(0.5, 0.5, "Нет таких объектов", ha='center', va='center', fontsize=12)
else:
    axes[1, 0].pie(prev_act_low_promo_categories, labels=prev_act_low_promo_categories.index, 
                   autopct='%1.1f%%', colors=colors_1, normalize=True)
    axes[1, 0].set_title('Прежний уровень активности: низкая акционная доля', fontweight='bold')

# фильтрация данных по условию promo_purchases > 0.5 для сниженного уровня активности
decr_act_high_promo = decr_act_customers[decr_act_customers['promo_purchases'] > 0.5]
decr_act_low_promo = decr_act_customers[decr_act_customers['promo_purchases'] < 0.5]

# получение категорий товаров и их количества для сниженного уровня активности с высокой акционной долей
decr_act_high_promo_categories = decr_act_high_promo['popular_category'].value_counts()
colors_2 = [category_colors.get(category, 'gray') for category in decr_act_high_promo_categories.index]
if decr_act_high_promo_categories.empty:
    axes[0, 1].text(0.5, 0.5, "Нет таких объектов", ha='center', va='center', fontsize=12)
    axes[0, 1].set_title('Снижение активности: высокая акционная доля', fontweight='bold')
else:
    axes[0, 1].pie(decr_act_high_promo_categories, labels=decr_act_high_promo_categories.index, 
                   autopct='%1.1f%%', colors=colors_2, normalize=True)
    axes[0, 1].set_title('Снижение активности: высокая акционная доля', fontweight='bold')

# Получение категорий товаров и их количества для сниженного уровня активности с низкой акционной долей
decr_act_low_promo_categories = decr_act_low_promo['popular_category'].value_counts()
colors_3 = [category_colors.get(category, 'gray') for category in decr_act_low_promo_categories.index]
if decr_act_low_promo_categories.empty:
    axes[1, 1].text(0.5, 0.5, "Нет таких объектов", ha='center', va='center', fontsize=12)
else:
    axes[1, 1].pie(decr_act_low_promo_categories, labels=decr_act_low_promo_categories.index, 
                   autopct='%1.1f%%', colors=colors_3, normalize=True)
    axes[1, 1].set_title('Снижение активности: низкая акционная доля', fontweight='bold')

plt.show()

# %% [markdown]
# Итак, наблюдаем интересный момент: снижение покупательской активности совпадает с тем, что **доля покупок по акциям не превышает `0.5`**.(для такой выборки даже нет данных для построения графика), значит магазин убрал акции на некоторые товары.

# %% [markdown]
# **Выводы:**
#
# Для более детального рассмотрения была выбрана целевая группа пользователей со среднемесячной прибылью, полученной магазином за последние 3 месяца, больше 4 (среднее значение прибыли) и высокой вероятностью снижения покупательской активности — более 0.7, далее мы смотрели, кто из них предпочитает пользоваться акциями на товары при покупке, и кто покупает вне зависимости от проводимых акций.
#
# В отобранной категории покупателей со сниженной покупательской активностью пракитчески в 7 раз меньше чем тех, чья покупательская активность осталась на прежнем уровне.
#
# `3/4` представителей данной группы принадлежит к стандартному типу обслуживания, примерно аналогичная доля пользователей разрешили компании осуществлять рассылку дополнительных предложений. Самой популярной категорией товаров у этой группы пользователей являются товары для детей (`21.6 %`) и домашний тестиль (`21 %`), остальные категории товаров представлены в меньшем процентном соотношении.
#
# За один видит они просматривают `3—5 категорий` товаров, просматривают `8—12 страниц` за визит, проводят на сайте в срежнем `11—17 минут` как в текущем, так и в предыдущем месяце, имеют в среднем `1-3 неоплаченных товара` в корзине за квартал, большая часть покупателей отобранной группы пользуются акциями, в подавляющем большинстве `доля покупок по акции меньше 0.5`.
#
# При более детальном рассмотрении этой группы было обнаружено, что снижение покупательской активности совпадает с тем, что доля покупок по акциям не превышает `0.5`. Можно предположить, что магазин убрал акции на некоторые товары, что привело к снижению покупательской активности.

# %% [markdown]
# ---------

# %% [markdown]
# Исходя из этого, можно сделать **следующие предложения по работе с этим сегментом покупателей для увеличения их активности**:
#
# 1. Используя данные о предпочтениях этой группы относительно категорий товаров для детей и домашнего текстиля, можно разработать персонализированные рекомендации товаров. Это поможет повысить их интерес и сделать покупки более привлекательными.
#
# 2. Учитывая, что эта группа пользователей была отобрана из-за высокой доли покупок по акции, можно разработать систему скидок или предложить выгодные акционные цены на посуду или мелкую бытовую технику и электронику, чтобы охватить категории товаров, которые пользуются не такой высокой популярностью у представителей данной группы.
#
# 3. В корзинах пользователей данной группы лежат неоплаченные товары, вероятно, как любители акций и скидок, они ждут акций на отложенные товары, чтобы сразу же купить их. Можно отследить ожидающие покупки товары и разработать выгодные акционные предложения.
#
# 4. Поскольку у большинства пользователей из этой группы разрешена рассылка рекламных материалов, можно завлечь клиентов на просмотр тех категорий товаров, которые раньше не пользовались у них спросом, предложив персональные скидки.

# %% [markdown]
# ## Общий вывод

# %% [markdown]
# <u>Задача</u>: разработать решение, которое позволит персонализировать предложения постоянным клиентам Интернет-магазина «В один клик», чтобы увеличить их покупательскую активность.
#
# Для работы было предоставлено четыре файла:
# * `market_file.csv`: таблица, которая содержит данные о поведении покупателя на сайте, о коммуникациях с покупателем и его продуктовом поведении.
# * `market_money.csv`: таблица с данными о выручке, которую получает магазин с покупателя, то есть сколько покупатель всего потратил за период взаимодействия с сайтом.
# * `market_time.csv`: таблица с данными о времени (в минутах), которое покупатель провёл на сайте в течение периода.
# * `money.csv`: таблица с данными о среднемесячной прибыли покупателя за последние 3 месяца: какую прибыль получает магазин от продаж каждому покупателю.
#
# На этапе предобработки были исправлены ошибки в обозначении временных периодов, удалены выбросы, дубликаты явные и неявные обнаружены не были, работы с пропусками также не было ввиду их отсутствия.
#
# Был проведен исследовательский анализ количественных и качественных признаков во всех предоставленных датафреймах, каких-либо аномальных или оторванных от реальности значений обнаружено не было.
#
# В соответствии с поставленной задачей требовалось отобрать клиентов с покупательской активностью не менее трех месяцев, то есть таких, которые что-либо покупали в этот период. Для этого были объединены таблицы, и получены полная таблица, отражающая активность покупателей за указанный срок. Был выполнен корреляционный анализ данных, представленных в этой таблице: выявлены признаки с высокой, умеренной, заметной, низкой и слабой корреляцией, отрицательной корреляции в данных не обнаружено.
#
# Для обучения были выбраны следующие модели: `KNeighborsClassifier()`, `DecisionTreeClassifier()`, `LogisticRegression()` и `SVC()` с различными параметрами и гиперпараметрами. Для подбора гиперпараметров и выбора лучшей модели использовался метод `RandomizedSearchCV`. Для облегчения работы использовались пайплайны с различными кодировщиками и скеллерами (`OneHotEncoder()`, `OrdinalEncoder()`, `StandardScaler()`, `MinMaxScaler()`). Лучшей моделью выбрана модель **SVC** (C=1, degree=4, gamma=1, kernel='linear', probability=True, random_state=42). Метрика лучшей модели на тренировочной выборке с округлением составляет `0.9`. Площадь под ROC-кривой с округлением составляет `0.9`. С помощью метода SHAP были отобраны наиболее важные признаки, которые лучшая модель учитывала при принятии решений.
#
# В качестве целевой группы были отобраны пользователи с высокой долей покупок по акции, с высокими затратами на покупки и с высокой вероятностью снижения покупательской активности.
#
# <u>Предложения по работе с этим сегментом покупателей</u>
#
# 1. Разработать персонализированные рекомендации товаров из категорий товаров для детей и домашнего текстиля, поскольку это наиболее популярные категории товаров, приобретаемых пользователями из данной группы.
#
# 2. Разработать систему скидок или предложить выгодные акционные цены на посуду или мелкую бытовую технику и электронику, чтобы охватить категории товаров, которые пользуются не такой высокой популярностью у представителей данной группы.
#
# 3. Отследить ожидающие покупки товары из корзин клиентов магазина, активно пользующихся скидками и акциями, и разработать выгодные акционные предложения для этих товаров.
#
# 4. Использовать рассылку для привлечения клиентов к покупке тех категорий товаров, которые раньше не пользовались у них спросом, предложив персональные скидки.
#
# В целом для увеличения пользовательской активности на сайте Интернет-магазина можно предоставить возможность оставлять отзывы о купленных товарах, вступать в сообщества с обсуждением интересных им тем, а также проводить опросы или голосования, чтобы учесть их мнение и предпочтения.
#
# Также нужно обеспечить высокий уровень поддержки для пользователей. Быстрые ответы на вопросы, помощь в выборе товаров, возможность вернуть или обменять товары при необходимости — все это сделает их покупательский опыт более приятным и комфортным, а это в свою очередь будет способствовать их повторному обращению в магазин.
